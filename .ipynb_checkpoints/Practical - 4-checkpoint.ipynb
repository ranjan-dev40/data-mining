# %% [markdown]
# ### 1. Reading and writing text files in Python

# %% [markdown]
# #### Python provides inbuilt functions for creating, writing, and reading files. There are two types of files that can be handled in python, normal text files and binary files (written in binary language, 0s, and 1s).
#
# Text files: In this type of file, Each line of text is terminated with a special character called EOL (End of Line), which is the new line character (‘\n’) in python by default.
#
# Binary files: In this type of file, there is no terminator for a line, and the data is stored after converting it into machine-understandable binary language.

# %% [markdown]
#  The read() method is going to read all of the content of the file as one string. This is a good method to use if you don't have a lot of content in the text file.
#
# In this example, I am using the read() method to print out a list of names from the demo.txt file:

# %%
file = open("demo.txt","r")
print(file.read())
file.close()
# Out:
# Software Development Life Cycle (SDLC)
# SDLC is a process that creates a structure of development of software. There are different phases within SDLC, and each phase has its various activities. It makes the development team able to design, create, and deliver a high-quality product.
#
# SDLC describes various phases of software development and the order of execution of phases. Each phase requires deliverable from the previous phase in a life cycle of software development. Requirements are translated into design, design into development and development into testing; after testing, it is given to the client.
#
# Let's see all the phases in detail:
#
# Different phases of the software development cycle
#
# 1. Requirement Phase
# ...

# %%
lines = ['Readme', 'How to write text files in Python']
with open('demo.txt', 'w') as f:
    f.writelines(lines)

# %%
file = open("demo.txt","r")
print(file.read())
file.close()
# Out:
# ReadmeHow to write text files in Python

# %% [markdown]
# ### 2. Reading Excel and CSV Files (use pandas)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# In order to read data from csv or excel files you can use pandas library. The function is read_csv() or read_excel() from pandas.
#
# You have to provide the file path as a string. Make sure the file name and extension is also given in the path.
#
# In the below example a file named “annual-enterprise-survey-2021-financial-year-provisional-csv.csv” is being read in python. The path is provided along with the file name with extension as a string. The separator is provided as comma “,”. Most of the time the CSV files will have separator as comma”,” but sometime it can be a tab or a special character like tilda “~” as well. Depending on the incoming file, you should specify the separator.
#
# The encoding = ‘latin-1’ means the character set to use. Default character set is utf-8 which works for most of the datasets, however is there are certain cases when the data was coded specifically in latin-1 characters, then utf-8 will fail, hence use encoding = ‘latin-1’ for such cases.

# %%
import pandas as pd


df = pd.read_csv(r'annual-enterprise-survey-2021-financial-year-provisional-csv.csv',delimiter='\t')

# %%
df
# Out:
#       Year,Industry_aggregation_NZSIOC,Industry_code_NZSIOC,Industry_name_NZSIOC,Units,Variable_code,Variable_name,Variable_category,Value,Industry_code_ANZSIC06
# 0      2021,Level 1,99999,All industries,Dollars (mil...
# 1      2021,Level 1,99999,All industries,Dollars (mil...
# 2      2021,Level 1,99999,All industries,Dollars (mil...
# 3      2021,Level 1,99999,All industries,Dollars (mil...
# 4      2021,Level 1,99999,All industries,Dollars (mil...
# ...                                                  ...
# 41710  2013,Level 3,ZZ11,Food product manufacturing,P...
# 41711  2013,Level 3,ZZ11,Food product manufacturing,P...
# 41712  2013,Level 3,ZZ11,Food product manufacturing,P...
# 41713  2013,Level 3,ZZ11,Food product manufacturing,P...
# 41714  2013,Level 3,ZZ11,Food product manufacturing,P...
#
# [41715 rows x 1 columns]

# %% [markdown]
# Most of you will be quite familiar with Excel files and why they are so widely used to store tabular data. So I’m going to jump right to the code and import an Excel file in Python using Pandas.
#
# Pandas has a very handy function called read_excel() to read Excel files:

# %%
# read Excel file into a DataFrame
df = pd.read_excel(r'file_example_XLS_50.xls')
# print values
df
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %% [markdown]
# ### 3. Reading Web-sites (use urllib3 or any other library)

# %%
# pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/python

import urllib3


http = urllib3.PoolManager()

url = 'http://instagram.com'

resp = http.request('GET', url)
print(resp.status)
# Out:
# 200

# %%
#!/usr/bin/python
import urllib3
import urllib.request

webUrl=urllib.request.urlopen('https://www.python.org/')

# print("result: "+str(webUrl.getCode()))

htmldata=webUrl.read()

print(htmldata)
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <!-- Google tag (gtag.js) -->\n    <script async src="https://www.googletagmanager.com/gtag/js?id=G-TF35YF9CVH"></script>\n    <script>\n      window.dataLayer = window.dataLayer || [];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'js\', new Date());\n      gtag(\'config\', \'G-TF35YF9CVH\');\n    </script>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js">\n\n    <meta name="applica
# ...

# %% [markdown]
# ### 4. Reading PDF Files (Use PyPDF2 or any other library)

# %%
# pip install PyPDF2
# Out:
# ...
#      ------------------------------------ 232.6/232.6 kB 547.6 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2
sample_pdf = open(r'example.pdf', mode='rb')
pdfdoc = PyPDF2.PdfReader(sample_pdf)

print(pdfdoc.metadata)
print(len(pdfdoc.pages))

for i in range(len(pdfdoc.pages)):
    current_page = pdfdoc.pages[i]
    print("===================")
    print("Content on page:" + str(i + 1))
    print("===================")
    print(current_page.extract_text())
# Out:
# {'/ModDate': "D:20230212045543Z00'00'", '/Creator': 'Edited with https://pdfresizer.com', '/CreationDate': "D:20230212045543Z00'00'", '/Producer': 'iOS Version 16.3 (Build 20D47) Quartz PDFContext'}
# 1
# ...
# Content on page:1
# ...

# %% [markdown]
# ### 5. Demonstrate Exception Handling Features with suitable examples of your choice

# %% [markdown]
# Handling an exception
# If you have some suspicious code that may raise an exception, you can defend your program by placing the suspicious code in a try: block. After the try: block, include an except: statement, followed by a block of code which handles the problem as elegantly as possible.

# %% [markdown]
# Syntax
#
#
# Here is simple syntax of try....except...else blocks −
#
#
#
# try:
#
#    You do your operations here;
#
#
#    ......................
# except ExceptionI:
#
#    If there is ExceptionI, then execute this block.
#
# except ExceptionII:
#
#    If there is ExceptionII, then execute this block.
#
#    ......................
#
# else:
#
#    If there is no exception then execute this block.

# %% [markdown]
# ### Example -1
#
# For each try block, there can be zero or more except blocks. Multiple except blocks allow us to handle each exception differently.
#
# The argument type of each except block indicates the type of exception that can be handled by it. For example,

# %%
try:
    
    even_numbers = [2,4,6,8]
    print(even_numbers[5])

except ZeroDivisionError:
    print("Denominator cannot be 0.")
    
except IndexError:
    print("Index Out of Bound.")

# Output: Index Out of Bound
# Out:
# Index Out of Bound.

# %% [markdown]
# ###  Example2:
#           Exception Handling Using try...except

# %%
try:
    numerator = 10
    denominator = 0

    result = numerator/denominator

    print(result)
except:
    print("Error: Denominator cannot be 0.")

# Output: Error: Denominator cannot be 0.
# Out:
# Error: Denominator cannot be 0.
