# %% [markdown]
# # Read csv file

# %%
import pandas as pd

data = pd.read_csv('dataset - dataset.csv')

print(data)
# Out:
#     Order ID       Product Name             Category  Price  Quantity  \
# 0       1001          iPhone 12          Electronics    999         1
# 1       1002         Samsung TV          Electronics    599         2
# 2       1003       Canon Camera          Electronics    399         1
# 3       1004        Macbook Air          Electronics   1299         1
# 4       1005            T-Shirt             Clothing     20         5
# 5       1006      Running Shoes             Footwear    100         3
# 6       1007          Desk Lamp      Home and Garden     30         2
# 7       1008              Dress             Clothing     50         1
# 8       1009        Smart Watch          Electronics    199         1
# 9       1010            Toaster      Home and Garden     25         1
# 10      1011         Headphones          Electronics    199         3
# 11      1012            Monitor          Electronics    299         1
# ...

# %% [markdown]
# # central tendency

# %%
print(data.mean())
# Out:
# Order ID        1020.5000
# Price            185.7750
# Quantity           1.6250
# Discount           0.0225
# Customer Age      34.6500
# dtype: float64
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1692\2101390418.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.mean())

# %%
print(data.median())
# Out:
# Order ID        1020.5
# Price             79.5
# Quantity           1.0
# Discount           0.0
# Customer Age      33.5
# dtype: float64
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1692\2279890642.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.median())

# %%
data.mode()
# Out:
#     Order ID       Product Name     Category  Price  Quantity  Discount  \
# 0       1001      Ankle Weights  Electronics   25.0       1.0       0.0
# 1       1002      Back Massager          NaN   30.0       NaN       NaN
# 2       1003           Backpack          NaN  149.0       NaN       NaN
# 3       1004     Baseball Glove          NaN    NaN       NaN       NaN
# 4       1005            Blender          NaN    NaN       NaN       NaN
# 5       1006             Blouse          NaN    NaN       NaN       NaN
# 6       1007  Bluetooth Speaker          NaN    NaN       NaN       NaN
# 7       1008          Bookshelf          NaN    NaN       NaN       NaN
# 8       1009       Canon Camera          NaN    NaN       NaN       NaN
# 9       1010       Cookware Set          NaN    NaN       NaN       NaN
# 10      1011          Desk Lamp          NaN    NaN       NaN       NaN
# 11      1012   Desktop Computer          NaN    NaN       NaN       NaN
# ...

# %% [markdown]
# #  dispersion

# %%
data.std()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1692\2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# Order ID         11.690452
# Price           296.258938
# Quantity          1.147740
# Discount          0.043780
# Customer Age      8.710589
# dtype: float64

# %%
data.skew()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1692\1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# Order ID        0.000000
# Price           2.583128
# Quantity        2.086982
# Discount        2.331605
# Customer Age    0.445661
# dtype: float64

# %% [markdown]
# # Use iteration and sorting to find the top 10 most popular products by quantitysold.

# %%
sorted_data = data.sort_values(ascending=False,by='Quantity')
print(sorted_data[0:10])
# Out:
#     Order ID     Product Name             Category  Price  Quantity  Discount  \
# 35      1036    Running Socks  Sports and Outdoors     10         5      0.00
# 4       1005          T-Shirt             Clothing     20         5      0.05
# 19      1020     Water Bottle      Home and Garden     10         5      0.00
# 10      1011       Headphones          Electronics    199         3      0.10
# 15      1016  Smartphone Case          Electronics     20         3      0.05
# 5       1006    Running Shoes             Footwear    100         3      0.00
# 14      1015          Blender      Home and Garden     49         2      0.00
# 31      1032         Football  Sports and Outdoors     25         2      0.00
# 25      1026   Running Shorts             Clothing     40         2      0.00
# 16      1017         Sneakers             Footwear     80         2      0.00
#
#     Order Date          Customer Email Customer Gender  Customer Age  \
# ...

# %% [markdown]
# # Use indexing and selecting data techniques to filter the dataset for ordersplaced on date 01-01-2022 and for customers who live in California.

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
jan_1_orders = data[data['Order Date'] == '2022-01-01']

# %%
california_orders = jan_1_orders[jan_1_orders['CustomerState'] == 'California']

# %%
california_orders = jan_1_orders[jan_1_orders['Customer State'] == 'California']
print(california_orders)
# Out:
#    Order ID Product Name     Category  Price  Quantity  Discount Order Date  \
# 0      1001    iPhone 12  Electronics    999         1       0.1 2022-01-01
# 1      1002   Samsung TV  Electronics    599         2       0.0 2022-01-01
#
#        Customer Email Customer Gender  Customer Age Customer State
# 0  john.doe@gmail.com            Male            30     California
# 1  jane.doe@gmail.com          Female            35     California

# %% [markdown]
# # Usestatistical functions to calculate the correlation between Price andQuantity, and between Discount and Quantity. Interpret the results.

# %%
frame = pd.DataFrame(data)
print( frame['Price'].corr(frame['Quantity']))
print (frame.corr())
# Out:
# -0.224217756612051
#               Order ID     Price  Quantity  Discount  Customer Age
# Order ID      1.000000 -0.424731 -0.153835 -0.400794      0.146800
# Price        -0.424731  1.000000 -0.224218  0.631238     -0.092676
# Quantity     -0.153835 -0.224218  1.000000 -0.031893      0.271222
# Discount     -0.400794  0.631238 -0.031893  1.000000     -0.301562
# Customer Age  0.146800 -0.092676  0.271222 -0.301562      1.000000

# %%
frame = pd.DataFrame(data)
print( frame['Discount'].corr(frame['Quantity']))
print (frame.corr())
# Out:
# -0.031893229748917944
#               Order ID     Price  Quantity  Discount  Customer Age
# Order ID      1.000000 -0.424731 -0.153835 -0.400794      0.146800
# Price        -0.424731  1.000000 -0.224218  0.631238     -0.092676
# Quantity     -0.153835 -0.224218  1.000000 -0.031893      0.271222
# Discount     -0.400794  0.631238 -0.031893  1.000000     -0.301562
# Customer Age  0.146800 -0.092676  0.271222 -0.301562      1.000000

# %% [markdown]
# # Create visualizations to explore the relationship between Customer Age and OrderDate, and between Category and Quantity. Include appropriate labels and
# .

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.scatter(data['Customer Age'], data['Order Date'])
plt.xlabel('Customer Age')
plt.ylabel('Order Date')
plt.title('Relationship between Customer Age and Order Date')
plt.show()

# %%
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.scatter(data['Category'], data['Quantity'])
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.title('Relationship between  Category  and Quantity')
plt.show()

# %%
from sklearn import preprocessing
df2 = pd.DataFrame(data,columns=['Price', 'Quantity'])
# print(df2)
float_array = df2[['Price','Quantity']].values.astype(float)
min_max_scaler = preprocessing.MinMaxScaler()
scaled_array = min_max_scaler.fit_transform(float_array)

df_normalized = pd.DataFrame(scaled_array)
print(df_normalized)
# Out:
#            0     1
# 0   0.767261  0.00
# 1   0.456943  0.25
# 2   0.301784  0.00
# 3   1.000000  0.00
# 4   0.007758  1.00
# 5   0.069822  0.50
# 6   0.015516  0.25
# 7   0.031032  0.00
# 8   0.146625  0.00
# 9   0.011637  0.00
# 10  0.146625  0.50
# 11  0.224205  0.00
# 12  0.107836  0.00
# 13  0.107836  0.00
# 14  0.030256  0.25
# 15  0.007758  0.50
# 16  0.054306  0.25
# 17  0.379364  0.00
# 18  0.054306  0.00
# 19  0.000000  1.00
# 20  0.007758  0.00
# 21  0.015516  0.00
# 22  0.031032  0.25
# 23  0.767261  0.00
# 24  0.107836  0.00
# 25  0.023274  0.25
# 26  0.053530  0.00
# 27  0.015516  0.00
# 28  0.069046  0.00
# 29  0.107836  0.00
# 30  0.031032  0.00
# 31  0.011637  0.25
# 32  0.069046  0.00
# 33  0.011637  0.00
# 34  0.092320  0.00
# 35  0.000000  1.00
# 36  0.023274  0.00
# 37  0.015516  0.00
# 38  0.069046  0.00
# 39  0.011637  0.00
